# %% [markdown]
# # Fig 2 e 6: Simulador Descentralizado - Resultados

# %% [markdown]
# - throughput total da rede versus número de estações (cenário estático): por enquanto para 5 e 15 estações

# %%
# %run my_comparison.py
# Out:
# /home/sheila/ns-allinone-3.29/ns-3.29/scratch/RLinWiFi-Decentralized-v08/graphs/my_comparison.py:74: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   plt.errorbar(RANGE, BEB, fmt='.-', label="BEB", marker="s", markersize=6, yerr=[0, 0, 0, 0])
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:689: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   return ax.errorbar(x, y, **kwds)
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:689: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   return ax.errorbar(x, y, **kwds)
# ...
